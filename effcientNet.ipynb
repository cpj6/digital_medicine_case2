# %%
# <reference>

# main
# https://github.com/wusaifei/HWCC_image_classification/blob/master/src/train.py

# data_transforms2
# https://github.com/Anjum48/rsna-ich

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install efficientnet_pytorch
# !pip install pydicom

# -*- coding: utf-8 -*-
from torchvision import datasets, transforms
import torch
from torch import nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data.dataloader import default_collate
from efficientnet_pytorch import EfficientNet
import numpy as np
import pydicom
import matplotlib.pyplot as plt
import glob
import os
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from PIL import Image
# Out:
# Requirement already satisfied: efficientnet_pytorch in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from efficientnet_pytorch) (1.7.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.16.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (1.18.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Requirement already satisfied: pydicom in /usr/local/lib/python3.6/dist-packages (2.1.1)

# %%
data_dir = "/content/drive/Shared drives/數位醫學/Case Presentation 2"

# hyper parameters
num_classes = 6
batch_size = 16
EPOCH = 45
#input_size = 256
input_size = 450
#input_size = 512

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# windowing
def correct_dcm(dcm):
    x = dcm.pixel_array + 1000
    px_mode = 4096
    x[x>=px_mode] = x[x>=px_mode] - px_mode
    dcm.PixelData = x.tobytes()
    dcm.RescaleIntercept = -1000

def window_image(dcm, window_center, window_width):
    
    if (dcm.BitsStored == 12) and (dcm.PixelRepresentation == 0) and (int(dcm.RescaleIntercept) > -100):
      correct_dcm(dcm)
    
    img = dcm.pixel_array * dcm.RescaleSlope + dcm.RescaleIntercept
    img_min = window_center - window_width // 2
    img_max = window_center + window_width // 2
    img = np.clip(img, img_min, img_max)

    return img

def bsb_window(dcm):
    brain_img = window_image(dcm, 40, 80)
    subdural_img = window_image(dcm, 80, 200)
    #soft_img = window_image(dcm, 40, 380)
    bone_img = window_image(dcm , 600 , 2800)

    brain_img = (brain_img - 0) / 80
    subdural_img = (subdural_img - (-20)) / 200
    #soft_img = (soft_img - (-150)) / 380
    bone_img = (bone_img - (-800)) / 2800

    #bsb_img = np.array([brain_img, subdural_img, soft_img]).transpose(1,2,0)
    bsb_img = np.array([brain_img, subdural_img, bone_img]).transpose(1,2,0)

    return bsb_img

# %%
class myDataset(Dataset):
  def __init__(self, folder, classes, transform=None):

    self.dictonary = {'epidural':0, 'healthy':1, 'intraparenchymal':2, 'intraventricular':3, 'subarachnoid':4, 'subdural':5}
    self.path = []
    self.label = []
    self.transform = transform

    # train data
    # self.path存dcm的path
    # self.label存dcm的label
    if len(classes) > 0:
      for i in classes:
        for j in glob.glob(folder + '/' + i + '/*'):
          self.path.append(j)
          self.label.append(self.dictonary[i])
    # test data的部分之後寫
    # 可能再寫一個test data的myDataset
    #else:
      #pass

  def __len__(self):
    return len(self.path)
 
  def __getitem__(self, idx):
    #img = torch.from_numpy(bsb_window(pydicom.dcmread(self.path[idx])).transpose(2, 0, 1)).type(torch.FloatTensor)

    img = bsb_window(pydicom.dcmread(self.path[idx])) # C*H*W => H*W*C
    # 以下動作使得圖片得以轉為PIL，才能使用部分的transform
    img *= 255 # [0., 1.] => [0., 255.]
    img = img.astype(np.uint8) # [0., 255.] => [0, 255]
    img = Image.fromarray(img) # numpy => PIL

    #print(np.max(np.array(img)), np.min(np.array(img)), np.mean(np.array(img)), np.median(np.array(img)))
    if self.transform:
      img = self.transform(img)
    #print(torch.max(img), torch.min(img), torch.mean(img), torch.median(img))
    return img, self.label[idx]

classes = ['epidural', 'healthy', 'intraparenchymal', 'intraventricular', 'subarachnoid', 'subdural']

# data augmentation
data_transforms1 = transforms.Compose([
  transforms.ToPILImage(),
  transforms.Resize(input_size),
  transforms.CenterCrop(input_size),
  transforms.RandomAffine(degrees=0, translate=(0.05, 0.05)),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(), # PIL => FloatTensor，[0, 255] => [0., 1.]
  transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

data_transforms2 = transforms.Compose([
  #transforms.ToPILImage(),                                       
  transforms.RandomHorizontalFlip(p=0.5),
  transforms.RandomRotation(degrees=15),
  transforms.RandomResizedCrop(input_size, scale=(0.85, 1.0), ratio=(0.8, 1.2)),
  transforms.ToTensor(), # PIL => FloatTensor，[0, 255] => [0., 1.]
])      

from albumentations import ShiftScaleRotate
import cv2
data_transforms3 = transforms.Compose([
  transforms.ToPILImage(), 
  transforms.Resize(input_size),                                      
  transforms.RandomHorizontalFlip(p=0.5),
  #ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=20, p=0.3, border_mode = cv2.BORDER_REPLICATE),
  transforms.RandomRotation(degrees=20),
  transforms.ToTensor(), # PIL => FloatTensor，[0, 255] => [0., 1.]
  transforms.Normalize(mean=[0.2236, 0.1819, 0.2523], std=[0.3245, 0.2956, 0.3133]),
])

#TrainDataset = myDataset(folder='/content/drive/Shared drives/數位醫學/Case Presentation 2/TrainingData_tmp', classes=classes, transform=transforms.Resize((input_size, input_size)))
#TrainDataset = myDataset(folder='/content/drive/Shared drives/數位醫學/Case Presentation 2/TrainingData_tmp', classes=classes, transform=data_transforms1)
TrainDataset = myDataset(folder='/content/drive/Shared drives/數位醫學/Case Presentation 2/TrainingData_tmp', classes=classes, transform=data_transforms2)
#TrainDataset = myDataset(folder='/content/drive/Shared drives/數位醫學/Case Presentation 2/TrainingData_tmp', classes=classes, transform=data_transforms3)

validation_split = .1
shuffle_dataset = True
random_seed = 2020

dataset_size = len(TrainDataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset:
  np.random.seed(random_seed)
  np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(TrainDataset, batch_size=batch_size, sampler=train_sampler, num_workers=4)
validation_loader = torch.utils.data.DataLoader(TrainDataset, batch_size=batch_size, sampler=valid_sampler, num_workers=4)

# %%
# load pretrained weight(trained from ImageNet)
net = EfficientNet.from_pretrained('efficientnet-b4', num_classes=num_classes)
#print(net)
net = net.to(device)
# Out:
# Loaded pretrained weights for efficientnet-b4

# %%
ii = 0
LR = 0.0005  # learning rate
best_acc = 0  # initialize best test accuracy

# loss function
criterion = nn.CrossEntropyLoss()

# optimizer
#optimizer = optim.Adam(net.parameters(), lr=LR)
optimizer = optim.Adam(net.parameters(), lr=LR, betas=(0.9, 0.999), eps=1e-9)
#optimizer = optim.SGD(net.parameters(), lr=LR, momentum=0.9)

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.7, patience=3, verbose=True)

# %%
# 載入
#net = torch.load('/content/drive/Shared drives/數位醫學/Case Presentation 2/Implementation/weights/model=b4__size=380__acc=75__epoch=58.pkl')

# %%
import datetime
#long running

## modified region ## 
iter_train = []
loss_train = []
loss_val = []
acc_train = []
valid_acc_train = [] 
epoch_train = []
y_label=[]
y_score=[]
## modified region ## 
best_val_acc = 0.0
best_val_loss = 5.0

for epoch in range(EPOCH):
  net.train()
  sum_loss = 0.0
  correct = 0.0
  total = 0.0
  LOSS_TRAIN = 0.0
  starttime = datetime.datetime.now()
  # training
  for i, data in enumerate(train_loader, 0):
    length = len(train_loader)
    input, target = data
    #print(target, type(target))
    input, target = input.to(device), target.to(device)
    
    optimizer.zero_grad()

    output = net(input)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()

    sum_loss += loss.item()
    _, predicted = torch.max(output.data, 1)
    total += target.size(0)
    correct += predicted.eq(target.data).cpu().sum()
    if i % 80 == 0:
      print('[epoch:%d, iter:%d] Loss: %.03f | Acc: %.3f%% ' 
        % (epoch + 1, (i + 1 + epoch * length), sum_loss / (i + 1),
        100. * float(correct) / float(total)))
    # modified #
    LOSS_TRAIN = sum_loss / (i + 1)  
      
  ## modified region ##    
  epoch_train.append(epoch)
  loss_train.append(LOSS_TRAIN)
  acc_train.append(100. * float(correct) / float(total))   
  ## modified region ## 

  # validation
  with torch.no_grad():
    correct = 0
    total = 0
    val_sum_loss = 0
    LOSS_VAL = 0
    for i, data in enumerate(validation_loader, 0):
      net.eval()
      images, labels = data
      images, labels = images.to(device), labels.to(device)
      outputs = net(images)
      # 取得分最高的那個類 (outputs.data的索引號)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      #------------FOR AUC----------------
      for j in outputs:
        j.cpu().numpy()
        y_score.append(j)
      for p,l in zip(predicted, labels):
        y_label.append(l.cpu().numpy())
      #------------FOR AUC----------------
    # modified #
      correct += (predicted == labels).cpu().sum()
      loss = criterion(outputs, labels)
      val_sum_loss += loss.item()
      LOSS_VAL = val_sum_loss / (i + 1)
    loss_val.append(LOSS_VAL)
    # modified #
    print('validation accuracy：%.3f%%' % (100. * float(correct) / float(total)))
    acc = 100. * float(correct) / float(total)
    # modified #
    valid_acc_train.append(100. * float(correct) / float(total))
    if acc > best_val_acc:
      print('save weight (acc)')
      torch.save(net, '/content/drive/Shared drives/數位醫學/Case Presentation 2/Implementation/weights/b4(acc).pkl')
      best_val_acc = acc
    if LOSS_VAL < best_val_loss:
      print('save weight (loss)')
      torch.save(net, '/content/drive/Shared drives/數位醫學/Case Presentation 2/Implementation/weights/b4(loss).pkl')
      best_val_loss = LOSS_VAL
    scheduler.step(acc)
  endtime = datetime.datetime.now()
  print((endtime - starttime).seconds," seconds")

print("Training Finished, Total EPOCH=%d" % EPOCH)
# Out:
# [epoch:1, iter:1] Loss: 1.792 | Acc: 18.750%
# [epoch:1, iter:81] Loss: 1.616 | Acc: 32.716%
# [epoch:1, iter:161] Loss: 1.525 | Acc: 38.160%
# [epoch:1, iter:241] Loss: 1.441 | Acc: 42.479%
# [epoch:1, iter:321] Loss: 1.380 | Acc: 45.600%
# validation accuracy：46.333%
# save weight (acc)
# save weight (loss)
# 496  seconds
# [epoch:2, iter:339] Loss: 1.232 | Acc: 37.500%
# [epoch:2, iter:419] Loss: 1.083 | Acc: 58.565%
# [epoch:2, iter:499] Loss: 1.057 | Acc: 60.404%
# [epoch:2, iter:579] Loss: 1.046 | Acc: 61.177%
# [epoch:2, iter:659] Loss: 1.032 | Acc: 62.130%
# validation accuracy：60.667%
# save weight (acc)
# save weight (loss)
# 275  seconds
# [epoch:3, iter:677] Loss: 0.497 | Acc: 81.250%
# [epoch:3, iter:757] Loss: 0.842 | Acc: 68.981%
# [epoch:3, iter:837] Loss: 0.916 | Acc: 66.071%
# [epoch:3, iter:917] Loss: 0.897 | Acc: 67.324%
# [epoch:3, iter:997] Loss: 0.894 | Acc: 67.601%
# validation accuracy：66.167%
# save weight (acc)
# save weight (loss)
# 272  seconds
# [epoch:4, iter:1015] Loss: 0.568 | Acc: 68.750%
# [epoch:4, iter:1095] Loss: 0.765 | Acc: 72.917%
# [epoch:4, iter:1175] Loss: 0.759 | Acc: 73.214%
# [epoch:4, iter:1255] Loss: 0.756 | Acc: 73.081%
# [epoch:4, iter:1335] Loss: 0.754 | Acc: 73.384%
# validation accuracy：67.500%
# save weight (acc)
# 272  seconds
# [epoch:5, iter:1353] Loss: 0.501 | Acc: 87.500%
# [epoch:5, iter:1433] Loss: 0.681 | Acc: 75.617%
# [epoch:5, iter:1513] Loss: 0.709 | Acc: 74.612%
# [epoch:5, iter:1593] Loss: 0.700 | Acc: 75.233%
# [epoch:5, iter:1673] Loss: 0.701 | Acc: 75.097%
# validation accuracy：67.833%
# save weight (acc)
# 272  seconds
# [epoch:6, iter:1691] Loss: 0.672 | Acc: 75.000%
# [epoch:6, iter:1771] Loss: 0.583 | Acc: 79.012%
# [epoch:6, iter:1851] Loss: 0.592 | Acc: 79.542%
# [epoch:6, iter:1931] Loss: 0.596 | Acc: 79.227%
# [epoch:6, iter:2011] Loss: 0.596 | Acc: 79.400%
# validation accuracy：69.333%
# save weight (acc)
# 272  seconds
# [epoch:7, iter:2029] Loss: 0.288 | Acc: 93.750%
# [epoch:7, iter:2109] Loss: 0.461 | Acc: 84.028%
# [epoch:7, iter:2189] Loss: 0.506 | Acc: 82.609%
# [epoch:7, iter:2269] Loss: 0.517 | Acc: 82.210%
# [epoch:7, iter:2349] Loss: 0.530 | Acc: 81.639%
# validation accuracy：69.833%
# save weight (acc)
# 272  seconds
# [epoch:8, iter:2367] Loss: 0.282 | Acc: 87.500%
# [epoch:8, iter:2447] Loss: 0.444 | Acc: 85.417%
# [epoch:8, iter:2527] Loss: 0.447 | Acc: 84.860%
# [epoch:8, iter:2607] Loss: 0.461 | Acc: 84.284%
# [epoch:8, iter:2687] Loss: 0.466 | Acc: 83.956%
# validation accuracy：71.833%
# save weight (acc)
# 272  seconds
# [epoch:9, iter:2705] Loss: 0.156 | Acc: 100.000%
# [epoch:9, iter:2785] Loss: 0.435 | Acc: 84.954%
# [epoch:9, iter:2865] Loss: 0.408 | Acc: 86.491%
# [epoch:9, iter:2945] Loss: 0.405 | Acc: 86.281%
# [epoch:9, iter:3025] Loss: 0.427 | Acc: 85.397%
# validation accuracy：72.000%
# save weight (acc)
# save weight (loss)
# 273  seconds
# [epoch:10, iter:3043] Loss: 0.581 | Acc: 81.250%
# [epoch:10, iter:3123] Loss: 0.316 | Acc: 88.735%
# [epoch:10, iter:3203] Loss: 0.333 | Acc: 88.509%
# [epoch:10, iter:3283] Loss: 0.355 | Acc: 87.552%
# [epoch:10, iter:3363] Loss: 0.369 | Acc: 87.033%
# validation accuracy：72.500%
# save weight (acc)
# 272  seconds
# [epoch:11, iter:3381] Loss: 0.124 | Acc: 100.000%
# [epoch:11, iter:3461] Loss: 0.255 | Acc: 91.435%
# [epoch:11, iter:3541] Loss: 0.271 | Acc: 90.877%
# [epoch:11, iter:3621] Loss: 0.283 | Acc: 90.171%
# [epoch:11, iter:3701] Loss: 0.304 | Acc: 89.467%
# validation accuracy：70.333%
# 272  seconds
# [epoch:12, iter:3719] Loss: 0.224 | Acc: 93.750%
# [epoch:12, iter:3799] Loss: 0.256 | Acc: 90.432%
# [epoch:12, iter:3879] Loss: 0.277 | Acc: 90.411%
# [epoch:12, iter:3959] Loss: 0.277 | Acc: 90.327%
# [epoch:12, iter:4039] Loss: 0.283 | Acc: 89.914%
# validation accuracy：69.167%
# 272  seconds
# [epoch:13, iter:4057] Loss: 0.106 | Acc: 100.000%
# [epoch:13, iter:4137] Loss: 0.220 | Acc: 92.901%
# [epoch:13, iter:4217] Loss: 0.246 | Acc: 91.693%
# [epoch:13, iter:4297] Loss: 0.250 | Acc: 91.390%
# [epoch:13, iter:4377] Loss: 0.270 | Acc: 90.790%
# validation accuracy：72.500%
# 272  seconds
# [epoch:14, iter:4395] Loss: 0.266 | Acc: 87.500%
# [epoch:14, iter:4475] Loss: 0.176 | Acc: 93.827%
# [epoch:14, iter:4555] Loss: 0.189 | Acc: 93.634%
# [epoch:14, iter:4635] Loss: 0.191 | Acc: 93.594%
# [epoch:14, iter:4715] Loss: 0.215 | Acc: 92.757%
# validation accuracy：72.167%
# Epoch    14: reducing learning rate of group 0 to 3.5000e-04.
# 272  seconds
# [epoch:15, iter:4733] Loss: 0.146 | Acc: 87.500%
# [epoch:15, iter:4813] Loss: 0.149 | Acc: 94.753%
# [epoch:15, iter:4893] Loss: 0.147 | Acc: 95.225%
# [epoch:15, iter:4973] Loss: 0.154 | Acc: 94.969%
# [epoch:15, iter:5053] Loss: 0.147 | Acc: 95.152%
# validation accuracy：71.333%
# 272  seconds
# [epoch:16, iter:5071] Loss: 0.104 | Acc: 93.750%
# [epoch:16, iter:5151] Loss: 0.101 | Acc: 96.914%
# [epoch:16, iter:5231] Loss: 0.108 | Acc: 96.467%
# [epoch:16, iter:5311] Loss: 0.110 | Acc: 96.629%
# [epoch:16, iter:5391] Loss: 0.106 | Acc: 96.690%
# validation accuracy：74.667%
# save weight (acc)
# 272  seconds
# [epoch:17, iter:5409] Loss: 0.063 | Acc: 100.000%
# [epoch:17, iter:5489] Loss: 0.077 | Acc: 97.145%
# [epoch:17, iter:5569] Loss: 0.083 | Acc: 97.089%
# [epoch:17, iter:5649] Loss: 0.083 | Acc: 97.147%
# [epoch:17, iter:5729] Loss: 0.087 | Acc: 97.079%
# validation accuracy：73.333%
# 272  seconds
# [epoch:18, iter:5747] Loss: 0.005 | Acc: 100.000%
# [epoch:18, iter:5827] Loss: 0.068 | Acc: 97.531%
# [epoch:18, iter:5907] Loss: 0.077 | Acc: 97.438%
# [epoch:18, iter:5987] Loss: 0.088 | Acc: 96.992%
# [epoch:18, iter:6067] Loss: 0.099 | Acc: 96.748%
# validation accuracy：71.667%
# 272  seconds
# [epoch:19, iter:6085] Loss: 0.024 | Acc: 100.000%
# [epoch:19, iter:6165] Loss: 0.099 | Acc: 96.451%
# [epoch:19, iter:6245] Loss: 0.102 | Acc: 96.623%
# [epoch:19, iter:6325] Loss: 0.098 | Acc: 96.836%
# [epoch:19, iter:6405] Loss: 0.102 | Acc: 96.729%
# validation accuracy：74.500%
# 272  seconds
# [epoch:20, iter:6423] Loss: 0.010 | Acc: 100.000%
# [epoch:20, iter:6503] Loss: 0.073 | Acc: 97.685%
# [epoch:20, iter:6583] Loss: 0.077 | Acc: 97.399%
# [epoch:20, iter:6663] Loss: 0.085 | Acc: 97.095%
# [epoch:20, iter:6743] Loss: 0.079 | Acc: 97.274%
# validation accuracy：74.000%
# Epoch    20: reducing learning rate of group 0 to 2.4500e-04.
# 272  seconds
# [epoch:21, iter:6761] Loss: 0.051 | Acc: 100.000%
# [epoch:21, iter:6841] Loss: 0.088 | Acc: 96.836%
# [epoch:21, iter:6921] Loss: 0.076 | Acc: 97.399%
# [epoch:21, iter:7001] Loss: 0.071 | Acc: 97.614%
# [epoch:21, iter:7081] Loss: 0.069 | Acc: 97.664%
# validation accuracy：74.667%
# 272  seconds
# [epoch:22, iter:7099] Loss: 0.003 | Acc: 100.000%
# [epoch:22, iter:7179] Loss: 0.029 | Acc: 99.228%
# [epoch:22, iter:7259] Loss: 0.027 | Acc: 99.262%
# [epoch:22, iter:7339] Loss: 0.032 | Acc: 99.092%
# [epoch:22, iter:7419] Loss: 0.035 | Acc: 98.929%
# validation accuracy：73.333%
# 272  seconds
# [epoch:23, iter:7437] Loss: 0.002 | Acc: 100.000%
# [epoch:23, iter:7517] Loss: 0.037 | Acc: 98.843%
# [epoch:23, iter:7597] Loss: 0.033 | Acc: 98.874%
# [epoch:23, iter:7677] Loss: 0.040 | Acc: 98.781%
# [epoch:23, iter:7757] Loss: 0.040 | Acc: 98.695%
# validation accuracy：74.500%
# 272  seconds
# [epoch:24, iter:7775] Loss: 0.001 | Acc: 100.000%
# [epoch:24, iter:7855] Loss: 0.055 | Acc: 98.148%
# [epoch:24, iter:7935] Loss: 0.058 | Acc: 98.020%
# [epoch:24, iter:8015] Loss: 0.052 | Acc: 98.211%
# [epoch:24, iter:8095] Loss: 0.054 | Acc: 98.131%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-110e0500d29f> in <module>()
#      69       #------------FOR AUC----------------
#      70       for j in outputs:
# ---> 71         j.cpu().numpy()
#      72         y_score.append(j)
#      73       for p,l in zip(predicted, labels):
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(12.8, 9.6)) 
plt.title("efficientNet-b4 accuracy")

plt.xlabel("Epoch")
plt.xlim(0 , len(epoch_train)-1)
plt.ylim(0 , 100)
plt.ylabel("Accuracy") 

plt.plot(epoch_train[:-1] , acc_train[:-1] , label = "Acc")
#plt.plot(epoch_train , loss_train , label = "Loss")
plt.plot(epoch_train[:-1] , valid_acc_train , label = "Valid_acc")
plt.legend(loc="upper left")
plt.grid()
plt.show()  
plt.savefig("InceptionV3.jpg")

# %%
plt.figure(figsize=(12.8, 9.6)) 
plt.title("efficientNet-b4 loss")

plt.xlabel("Epoch")
#plt.xlim(0 , len(epoch_train)-1)
#plt.ylim(0 , 4)
plt.ylabel("Loss") 

plt.plot(epoch_train[:-1] , loss_train[:-1] , label = "Loss")
plt.plot(epoch_train[:-1] , loss_val , label = "Loss_validation")
plt.legend(loc="upper left")
plt.grid()
plt.show()

# %%
#torch.save(net, '/content/drive/Shared drives/數位醫學/Case Presentation 2/Implementation/epoch60.pkl')

# %%
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from scipy import interp
_y_score = np.array([F.softmax(x.to("cpu"),dim=0).numpy().tolist() for x in y_score])
_y_label = [x.item() for x in y_label]
one_hot_label = []

for i in range(len(_y_label)):
  six_zero = [0, 0, 0, 0, 0, 0]
  six_zero[_y_label[i]] = 1
  one_hot_label.append(six_zero)
one_hot_label = np.array(one_hot_label)


n_classes = 6
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
  fpr[i], tpr[i], _ = roc_curve(one_hot_label[:, i], _y_score[:, i])
  roc_auc[i] = auc(fpr[i], tpr[i])

# macro（方法一）
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
  mean_tpr += interp(all_fpr, fpr[i], tpr[i])
# Finally average it and compute AUC
mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
 
# Plot all ROC curves
lw=2
plt.figure()
 
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)
 
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'lime', 'violet', 'hotpink'])

classes_name = ['epidural', 'healthy', 'intraparenchymal', 'intraventricular', 'subarachnoid', 'subdural']

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of {0} (area = {1:0.2f})'
             ''.format(classes_name[i], roc_auc[i]))

plt.rcParams["figure.figsize"] = (5,5)
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('multi-calss ROC')
plt.legend(loc="lower right")
plt.grid()
plt.show()
